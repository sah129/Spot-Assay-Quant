# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy as np
from os import listdir
# %matplotlib inline
from functools import reduce

# %%
output_class = "Results"
base_path = "C:/Users/sarah/Desktop/SpotAssayQuant/Examples/Grayscale/" + output_class + "/"

object_file = base_path + "Spreadsheets/SpotAsssayQuant_EditedObjects.csv"
image_file = base_path + "Spreadsheets/SpotAsssayQuant_Image.csv"


df = pd.read_csv(object_file)
df = df[["ImageNumber","ObjectNumber","AreaShape_Area", "Classify_Row1", "Classify_Row2", "Classify_Row3", "Classify_Row4", "Classify_Row5", "Classify_Row6", "Classify_Row7"]]
df = df.rename(columns = {'AreaShape_Area': 'Area','Classify_Row1':'Row1','Classify_Row2':'Row2','Classify_Row3':'Row3','Classify_Row4':'Row4','Classify_Row5':'Row5','Classify_Row6':'Row6', 'Classify_Row7':'Row7'})

image_names = pd.read_csv(image_file)
image_df = image_names[["FileName_original", "ImageNumber"]] #include other stuff later
df = df.merge(image_df, on = "ImageNumber")

# %%
rowareas
# Out:
#                                                        Row1    Row2    Row3  \
# FileName_original
# (A) atg19D 6 days rapa50 7-22-19 (1) binary.tif        54.0  5530.0     0.0
# (A) atg19D 6 days rapa50 7-22-19 (2) binary.tif       179.0  7838.0     0.0
# (A) atg32D 6 days rapa50 7-22-19 (1) binary.tif       647.0  7997.0     0.0
# (A) atg32D 6 days rapa50 7-22-19 (2) binary.tif       944.0  7869.0     0.0
# (A) atg36D 6 days rapa50  7-22-19 (1) binary.tif     5470.0  8629.0  1189.0
# (A) atg36D 6 days rapa50 7-22-19 (2) binary.tif     10762.0  9506.0     0.0
# (A) atg39D 6 days rapa50 7-22-19(1) binary.tif        245.0  2890.0  4973.0
# (A) atg39D 6 days rapa50 7-22-19(2) binary.tif        517.0  7881.0     0.0
# (A) atg40D 6 days rapa50 7-22-19(1) binary.tif       4052.0  2098.0  5453.0
# (A) atg40D 6 days rapa50 7-22-19(2) binary.tif       3559.0  6333.0   709.0
# (A) atg8D 6 days rapa50 7-22-19 (2) binary.tif         31.0  1869.0  4428.0
# (A) atg9D 6 days rapa50  7-22-19 (1) binary.tif       106.0  2071.0  5492.0
# (A) atg9D 6 days rapa50  7-22-19 (2) binary.tif       746.0  3666.0  4659.0
# (A) cue5D 6 days rapa50 7-22-19(1) binary.tif        1713.0  9750.0   881.0
# (A) cue5D 6 days rapa50 7-22-19(2) binary.tif        2345.0  5275.0  5824.0
# (B) atg19D 6 days rapa50 7-29-19 (1) binary.tif        18.0  8805.0     0.0
# (B) atg19D 6 days rapa50 7-29-19 (2) binary.tif        57.0  9568.0     0.0
# (B) atg32D 6 days rapa50 7-29-19  (1) binary.tif      162.0  6125.0  2099.0
# (B) atg32D 6 days rapa50 7-29-19(2) binary.tif          7.0  2673.0  4287.0
# (B) atg36D 6 days rapa50 7-29-19 (1) binary.tif       153.0  6155.0  2636.0
# (B) atg39D 6 days rapa50 7-29-19(1) binary.tif        240.0  5601.0  2229.0
# (C) atg8D  6 days  rapa50 7-30-19 (1) binary.tif     3941  4993.0      0.0
# (C) atg8D 6 days rapa50  7-30-19 (2) binary.tif      4076  5040.0      0.0
# (C) cue5D 6 days rapa50 7-30-19(1) binary.tif        3921  4696.0      0.0
# (C) cue5D 6 days rapa50 7-30-19(2) binary.tif        4448  5669.0      0.0
# (A) atg34D 6 days rapa50 7-22-19 (2) binary.tif      1705    97.0      0.0
# (A) atg8D 6 days rapa50 7-22-19 (1) binary.tif       3552  3395.0     13.0
# (B) atg34D 6 days rapa50 7-29-19 (1) binary.tif      5139     0.0      1.0
# (B) atg34D 6 days rapa50 7-29-19(2) binary.tif        249  5266.0      0.0
# (B) atg8D 6 days rapa50  7-29-19 (1) binary.tif      3937  3021.0      0.0
# (C) atg19D 6 days rapa50 7-30-19 (1) binary.tif     10530     0.0      0.0
# (A) atg34D 6 days rapa50 7-22-19(1) binary.tif       2604     5.0      0.0
#
#                                                      Row7
# FileName_original
# (A) atg19D 6 days rapa50 7-22-19 (1) binary.tif       0.0
# (A) atg19D 6 days rapa50 7-22-19 (2) binary.tif       0.0
# (A) atg32D 6 days rapa50 7-22-19 (1) binary.tif       0.0
# (A) atg32D 6 days rapa50 7-22-19 (2) binary.tif       0.0
# (A) atg36D 6 days rapa50  7-22-19 (1) binary.tif      0.0
# (A) atg36D 6 days rapa50 7-22-19 (2) binary.tif     149.0
# (A) atg39D 6 days rapa50 7-22-19(1) binary.tif        0.0
# (A) atg39D 6 days rapa50 7-22-19(2) binary.tif        0.0
# (A) atg40D 6 days rapa50 7-22-19(1) binary.tif        0.0
# (A) atg40D 6 days rapa50 7-22-19(2) binary.tif        0.0
# (A) atg8D 6 days rapa50 7-22-19 (2) binary.tif        0.0
# (A) atg9D 6 days rapa50  7-22-19 (1) binary.tif       0.0
# (A) atg9D 6 days rapa50  7-22-19 (2) binary.tif       0.0
# (A) cue5D 6 days rapa50 7-22-19(1) binary.tif         0.0
# (A) cue5D 6 days rapa50 7-22-19(2) binary.tif         0.0
# (B) atg19D 6 days rapa50 7-29-19 (1) binary.tif       0.0
# (B) atg19D 6 days rapa50 7-29-19 (2) binary.tif       0.0
# (B) atg32D 6 days rapa50 7-29-19  (1) binary.tif      0.0
# (B) atg32D 6 days rapa50 7-29-19(2) binary.tif        0.0
# (B) atg36D 6 days rapa50 7-29-19 (1) binary.tif       0.0
# (B) atg39D 6 days rapa50 7-29-19(1) binary.tif        0.0
# (B) atg39D 6 days rapa50 7-29-19(2) binary.tif        0.0
# (B) atg8D 6 days rapa50 ura-  7-29-19 (2) binar...    0.0
# (B) atg9D 6 days rapa50 7-29-19 (1) binary.tif        0.0
# (B) atg9D 6 days rapa50 7-29-19 (2) binary.tif        0.0
# (B) cue5D 6 days rapa50 7-29-19(1) binary.tif         0.0
# (B) cue5D 6 days rapa50 7-29-19(2) binary.tif         0.0
# (C) atg19D 6 days rapa50 7-30-19 (2) binary.tif       0.0
# (C) atg32D 6 days rapa50 7-30-19 (1) binary.tif       0.0
# (C) atg32D 6 days rapa50 7-30-19 (2) binary.tif       0.0
# (C) atg34D 6 days rapa50 7-30-19 (1) binary.tif       0.0
# (C) atg34D 6 days rapa50 7-30-19 (2) binary.tif       0.0
# (C) atg36D 6 days rapa50 7-30-19(1) binary.tif        0.0
# (C) atg36D 6 days rapa50 7-30-19(2) binary.tif        0.0
# (C) atg39D 6 days rapa50 7-30-19 (1) binary.tif       0.0
# (C) atg39D 6 days rapa50 7-30-19(2) binary.tif        0.0
# (C) atg40D 6 days rapa50 7-30-19 (1) binary.tif       0.0
# (C) atg40D 6 days rapa50 7-30-19(2) binary.tif        0.0
# (C) atg8D  6 days  rapa50 7-30-19 (1) binary.tif      0.0
# (C) atg8D 6 days rapa50  7-30-19 (2) binary.tif       0.0
# (C) cue5D 6 days rapa50 7-30-19(1) binary.tif         0.0
# (C) cue5D 6 days rapa50 7-30-19(2) binary.tif         0.0
# (A) atg34D 6 days rapa50 7-22-19 (2) binary.tif       0.0
# (A) atg8D 6 days rapa50 7-22-19 (1) binary.tif        0.0
# (B) atg34D 6 days rapa50 7-29-19 (1) binary.tif       0.0
# (B) atg34D 6 days rapa50 7-29-19(2) binary.tif        0.0
# (B) atg8D 6 days rapa50  7-29-19 (1) binary.tif       0.0
# (C) atg19D 6 days rapa50 7-30-19 (1) binary.tif       0.0
# (A) atg34D 6 days rapa50 7-22-19(1) binary.tif        0.0

# %%
row_names = df.filter(regex="Row.*").columns.values
dfs = []
for r in row_names:
    dfs.append(df.loc[df[r]==1].groupby("FileName_original")["Area"].sum().rename(r).reset_index())

# %%
rowareas = reduce(lambda left,right: pd.merge(left,right,on='FileName_original', how = "outer"), dfs)
rowareas= rowareas.fillna(0)
rowareas = rowareas.set_index("FileName_original")

# %%
with PdfPages(base_path + "Graphs/Result_graphs.pdf") as pdf:
    for index, row in rowareas.iterrows():
        fig, ax = plt.subplots(1,2)
        fig.suptitle(row.name, y = 1.08)
        fig.patch.set_visible(False)

        ax[0].axis('off')
        ax[0].axis('tight')
        ax[0].table(cellText=[row.values], colLabels=row.index, loc='center')

        plot = row.plot(ax = ax[1], kind='barh')
        plt.gca().invert_yaxis() 
       # ax[1].get_legend().remove()

        fig.tight_layout()
        plt.show()
        pdf.savefig(fig,bbox_inches='tight')
        
with PdfPages(base_path + "Graphs/Result_table.pdf") as pdf:
    fig = plt.figure(figsize=(9,2))
    ax = plt.subplot(111)
    ax.axis('off')
    ax.axis('tight')
    #fig.suptitle(output_class + ' Areas', y = 1.08)
    ax.table(cellText=rowareas.values, colLabels=rowareas.columns,  rowLabels=rowareas.index,  loc='center')
    #fig.tight_layout()

    pdf.savefig(fig,bbox_inches='tight')

# %%
rowareas.to_csv(base_path + "/Graphs/"+output_class+" Results.csv")
